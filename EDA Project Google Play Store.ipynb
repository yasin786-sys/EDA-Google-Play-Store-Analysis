# %%
            ##QUESTIONS
#1. Display Top 5 Rows of The Dataset
#2. Check the Last 3 Rows of The Dataset
#3. Find Shape of Our Dataset (Number of Rows & Number of Columns)
#4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column 
 #  And  Memory Requirement
#5. Get Overall Statistics About The Dataframe OR Get the Descriptive Statistics about Google Play Store
#6. Obtain Total Number of App Titles Contain Astrology
#7. Find Average App Rating
#8.  Find Total Number of Unique Category
#9. Which Category Getting The Highest Average Rating?
#10. Find Total Number of App having 5 Star Rating
#11. Find Average Value of Reviews
#12. Find Total Number of Free and Paid Apps
#13.  Which App Has Maximum Reviews?
#14. Display Top 5 Apps Having Highest Reviews
#15. Find Average Rating of Free and Paid Apps
#16. Display Top  5 Apps Having Maximum Installs

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.expand_frame_repr", False)

# %%
#Read the Records from Google Play Store Related CSV File
import pandas as pd
import numpy as np
df=pd.read_csv("D:\\PANDAS\\Google Play Store.csv")
print(df)
# Out:
#                                                      App             Category  Rating Reviews                Size     Installs  Type Price Content Rating                     Genres      Last Updated         Current Ver         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN     4.1     159                 19M      10,000+  Free     0       Everyone               Art & Design   January 7, 2018               1.0.0        4.0.3 and up
# 1                                    Coloring book moana       ART_AND_DESIGN     3.9     967                 14M     500,000+  Free     0       Everyone  Art & Design;Pretend Play  January 15, 2018               2.0.0        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN     4.7   87510                8.7M   5,000,000+  Free     0       Everyone               Art & Design    August 1, 2018               1.2.4        4.0.3 and up
# ...

# %%
#Sample-1. Find Total Number Apps in Google Play Store
df.shape
# Out:
# (10841, 13)

# %%
print("Find Total Number Apps in Google Play Store=",df.shape[0])
# Out:
# Find Total Number Apps in Google Play Store= 10841

# %%
print("Find Total Number of column Apps in Google Play Store=",df.shape[1])
# Out:
# Find Total Number of column Apps in Google Play Store= 13

# %%
#1. Display Top 5 Rows of The Dataset
df.head(5) # OR df.head()
# Out:
#                                                  App        Category  Rating Reviews  Size     Installs  Type Price Content Rating                     Genres      Last Updated         Current Ver   Android Ver
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1     159   19M      10,000+  Free     0       Everyone               Art & Design   January 7, 2018               1.0.0  4.0.3 and up
# 1                                Coloring book moana  ART_AND_DESIGN     3.9     967   14M     500,000+  Free     0       Everyone  Art & Design;Pretend Play  January 15, 2018               2.0.0  4.0.3 and up
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7   87510  8.7M   5,000,000+  Free     0       Everyone               Art & Design    August 1, 2018               1.2.4  4.0.3 and up
# ...

# %%
#2. Check the Last 3 Rows of The Dataset
df.tail(3)
# Out:
#                                                  App             Category  Rating Reviews                Size     Installs  Type Price Content Rating             Genres      Last Updated         Current Ver         Android Ver
# 10838                         Parkinson Exercices FR              MEDICAL     NaN       3                9.5M       1,000+  Free     0       Everyone            Medical  January 20, 2017                 1.0          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+  Free     0     Mature 17+  Books & Reference  January 19, 2015  Varies with device  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE     4.5  398307                 19M  10,000,000+  Free     0       Everyone          Lifestyle     July 25, 2018  Varies with device  Varies with device

# %%
# OR
df[len(df)-3:]
# Out:
#                                                  App             Category  Rating Reviews                Size     Installs  Type Price Content Rating             Genres      Last Updated         Current Ver         Android Ver
# 10838                         Parkinson Exercices FR              MEDICAL     NaN       3                9.5M       1,000+  Free     0       Everyone            Medical  January 20, 2017                 1.0          2.2 and up
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5     114  Varies with device       1,000+  Free     0     Mature 17+  Books & Reference  January 19, 2015  Varies with device  Varies with device
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE     4.5  398307                 19M  10,000,000+  Free     0       Everyone          Lifestyle     July 25, 2018  Varies with device  Varies with device

# %%
#3. Find Shape of Our Dataset (Number of Rows & Number of Columns)
print("Shape of Google Play Store DataSet=",df.shape)
print("Number of Rows=",df.shape[0])
print("Number of Columns=",df.shape[1])
# Out:
# Shape of Google Play Store DataSet= (10841, 13)
# Number of Rows= 10841
# Number of Columns= 13

# %%
#4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column 
 #  And  Memory Requirement
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  str
#  1   Category        10841 non-null  str
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  str
#  4   Size            10841 non-null  str
#  5   Installs        10841 non-null  str
#  6   Type            10840 non-null  str
#  7   Price           10841 non-null  str
#  8   Content Rating  10840 non-null  str
#  9   Genres          10841 non-null  str
#  10  Last Updated    10841 non-null  str
#  11  Current Ver     10833 non-null  str
#  12  Android Ver     10838 non-null  str
# dtypes: float64(1), str(12)
# memory usage: 1.1 MB

# %%
#5. Get Overall Statistics About The Dataframe OR
#Get the Descriptive Statistics about Google Play Store
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs   Type  Price Content Rating Genres    Last Updated         Current Ver Android Ver
# count    10841    10841  9367.000000   10841               10841       10841  10840  10841          10840  10841           10841               10833       10838
# unique    9660       34          NaN    6002                 462          22      3     93              6    120            1378                2832          33
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+   Free      0       Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq         9     1972          NaN     596                1695        1579  10039  10040           8714    842             326                1459        2451
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN    NaN    NaN            NaN    NaN             NaN                 NaN         NaN
# ...

# %%
# 6. Obtain Total Number of App Titles Contain 'Astrology'
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df["App"]
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: str

# %%
df["App"].str.contains("Astrology")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840     True
# Name: App, Length: 10841, dtype: bool

# %%
df[df["App"].str.contains("Astrology")]
# Out:
#                                                      App   Category  Rating Reviews Size     Installs  Type Price Content Rating     Genres   Last Updated         Current Ver         Android Ver
# 1570   Horoscopes – Daily Zodiac Horoscope and Astrology  LIFESTYLE     4.6  161143  11M  10,000,000+  Free     0   Everyone 10+  Lifestyle  June 25, 2018          5.2.4(881)        4.0.3 and up
# 1592              သိင်္ Astrology - Min Thein Kha BayDin  LIFESTYLE     4.7    2225  15M     100,000+  Free     0       Everyone  Lifestyle  July 26, 2018               4.2.1        4.0.3 and up
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  LIFESTYLE     4.5  398307  19M  10,000,000+  Free     0       Everyone  Lifestyle  July 25, 2018  Varies with device  Varies with device

# %%
df[df["App"].str.contains("Astrology")]["App"]
# Out:
# 1570     Horoscopes – Daily Zodiac Horoscope and Astrology
# 1592                သိင်္ Astrology - Min Thein Kha BayDin
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, dtype: str

# %%
df[df["App"].str.contains("Astrology",case=False)]["App"]
# Out:
# 1570     Horoscopes – Daily Zodiac Horoscope and Astrology
# 1592                သိင်္ Astrology - Min Thein Kha BayDin
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, dtype: str

# %%
print("-----------------------------------------")
print("App Titles Contain 'Astrology'")
print("-----------------------------------------")
for appname in df[df["App"].str.contains("Astrology",case=False)]["App"]:
 print(appname)
print("-----------------------------------------")
# Out:
# -----------------------------------------
# App Titles Contain 'Astrology'
# -----------------------------------------
# Horoscopes – Daily Zodiac Horoscope and Astrology
# သိင်္ Astrology - Min Thein Kha BayDin
# iHoroscope - 2018 Daily Horoscope & Astrology
# -----------------------------------------

# %%
#7. Find Average App Rating
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df["Rating"]
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
print("Average App Rating in Google Play Store=",df["Rating"].mean())
# Out:
# Average App Rating in Google Play Store= 4.193338315362443

# %%
#8. Find Total Number of Unique Category
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df["Category"]
# Out:
# 0             ART_AND_DESIGN
# 1             ART_AND_DESIGN
# 2             ART_AND_DESIGN
# 3             ART_AND_DESIGN
# 4             ART_AND_DESIGN
#                 ...
# 10836                 FAMILY
# 10837                 FAMILY
# 10838                MEDICAL
# 10839    BOOKS_AND_REFERENCE
# 10840              LIFESTYLE
# Name: Category, Length: 10841, dtype: str

# %%
df["Category"].unique()
# Out:
# <StringArray>
# [     'ART_AND_DESIGN',   'AUTO_AND_VEHICLES',              'BEAUTY',
#  'BOOKS_AND_REFERENCE',            'BUSINESS',              'COMICS',
#        'COMMUNICATION',              'DATING',           'EDUCATION',
#        'ENTERTAINMENT',              'EVENTS',             'FINANCE',
#       'FOOD_AND_DRINK',  'HEALTH_AND_FITNESS',      'HOUSE_AND_HOME',
#   'LIBRARIES_AND_DEMO',           'LIFESTYLE',                'GAME',
#               'FAMILY',             'MEDICAL',              'SOCIAL',
#             'SHOPPING',         'PHOTOGRAPHY',              'SPORTS',
#     'TRAVEL_AND_LOCAL',               'TOOLS',     'PERSONALIZATION',
#         'PRODUCTIVITY',           'PARENTING',             'WEATHER',
#        'VIDEO_PLAYERS',  'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#                  '1.9']
# Length: 34, dtype: str

# %%
print("Total Number of Unique Category=",df["Category"].nunique())
# Out:
# Total Number of Unique Category= 34

# %%
#Categoryt Names with Total Number of same Category
df["Category"].value_counts()
# Out:
# Category
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# COMICS                   60
# PARENTING                60
# ...

# %%
#App Names with Unique Category
for appname in df["Category"].unique():
 print(appname)
# Out:
# ART_AND_DESIGN
# AUTO_AND_VEHICLES
# BEAUTY
# BOOKS_AND_REFERENCE
# BUSINESS
# COMICS
# COMMUNICATION
# DATING
# EDUCATION
# ENTERTAINMENT
# EVENTS
# FINANCE
# FOOD_AND_DRINK
# HEALTH_AND_FITNESS
# HOUSE_AND_HOME
# LIBRARIES_AND_DEMO
# LIFESTYLE
# GAME
# FAMILY
# MEDICAL
# SOCIAL
# SHOPPING
# PHOTOGRAPHY
# SPORTS
# TRAVEL_AND_LOCAL
# TOOLS
# PERSONALIZATION
# PRODUCTIVITY
# PARENTING
# WEATHER
# VIDEO_PLAYERS
# NEWS_AND_MAGAZINES
# MAPS_AND_NAVIGATION
# 1.9

# %%
#9. Which Category Getting The Highest Average Rating?
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
appname=df.groupby("Category")['Rating'].mean().sort_values(ascending=False)
print("Category Getting The Highest Average Rating=",appname)
# Out:
# Category Getting The Highest Average Rating= Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ...

# %%
#10. Find Total Number of Apps having 5 Star Rating
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df["Rating"]
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
df["Rating"]==5
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837     True
# 10838    False
# 10839    False
# 10840    False
# Name: Rating, Length: 10841, dtype: bool

# %%
df[df["Rating"]==5]
# Out:
#                                               App   Category  Rating Reviews  Size Installs  Type Price Content Rating     Genres       Last Updated Current Ver   Android Ver
# 329                  Hojiboy Tojiboyev Life Hacks     COMICS     5.0      15   37M   1,000+  Free     0       Everyone     Comics      June 26, 2018         2.0  4.0.3 and up
# 612                 American Girls Mobile Numbers     DATING     5.0       5  4.4M   1,000+  Free     0     Mature 17+     Dating      July 17, 2018         3.0  4.0.3 and up
# 615                                  Awake Dating     DATING     5.0       2   70M     100+  Free     0     Mature 17+     Dating      July 24, 2018       2.2.9    4.4 and up
# 633                         Spine- The dating app     DATING     5.0       5  9.3M     500+  Free     0           Teen     Dating      July 14, 2018         4.0  4.0.3 and up
# ...

# %%
print("Total Number of Apps having 5 Star Rating=",len(df[df["Rating"]==5]))
# Out:
# Total Number of Apps having 5 Star Rating= 274

# %%
#11. Find Average Value of Reviews
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
#11. Find Average Value of Reviews
df["Reviews"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["Reviews"].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df["Reviews"].astype("float")
#
# File c:\Users\yasin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File c:\Users\yasin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
df[df["Reviews"]=='3.0M']
# Out:
#                                            App Category  Rating Reviews    Size Installs Type     Price Content Rating             Genres Last Updated Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M  1,000+     Free    0  Everyone            NaN  February 11, 2018       1.0.19  4.0 and up         NaN

# %%
df["Reviews"]=df["Reviews"].replace("3.0M",3000000.0)

# %%
df.loc[10472]
# Out:
# App               Life Made WI-Fi Touchscreen Photo Frame
# Category                                              1.9
# Rating                                               19.0
# Reviews                                         3000000.0
# Size                                               1,000+
# Installs                                             Free
# Type                                                    0
# Price                                            Everyone
# Content Rating                                        NaN
# Genres                                  February 11, 2018
# Last Updated                                       1.0.19
# Current Ver                                    4.0 and up
# Android Ver                                           NaN
# Name: 10472, dtype: object

# %%
df["Reviews"]=df["Reviews"].astype("float")
df["Reviews"].dtype
# Out:
# dtype('float64')

# %%
print("Average Value of Reviews=",df["Reviews"].mean())
# Out:
# Average Value of Reviews= 444388.6535374965

# %%
##12. Find Total Number of Free and Paid Apps
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df.groupby("Type").size()
# Out:
# Type
# 0           1
# Free    10039
# Paid      800
# dtype: int64

# %%
print("Total Number of Free and Paid Apps")
print(df["Type"].value_counts())
print("------------OR------------------")
print(df.groupby("Type").size())
# Out:
# Total Number of Free and Paid Apps
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64
# ------------OR------------------
# Type
# 0           1
# Free    10039
# Paid      800
# dtype: int64

# %%
#13. Find which app has Maximum Review
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df['Reviews'].max()
# Out:
# np.float64(78158306.0)

# %%
df['Reviews'].max()==df['Reviews']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
df[df['Reviews'].max()==df['Reviews']]
# Out:
#            App Category  Rating     Reviews                Size        Installs  Type Price Content Rating  Genres    Last Updated         Current Ver         Android Ver
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device  1,000,000,000+  Free     0           Teen  Social  August 3, 2018  Varies with device  Varies with device

# %%
df[df['Reviews'].max()==df['Reviews']]["App"].values[0]
# Out:
# 'Facebook'

# %%
df.iloc[df['Reviews'].sort_values(ascending=False).index[0]]["App"]
# Out:
# 'Facebook'

# %%
#14#Find the Top 5 App Names having highest Review
df["Reviews"].sort_values(ascending=False)
# Out:
# 2544     78158306.0
# 3943     78128208.0
# 381      69119316.0
# 336      69119316.0
# 3904     69109672.0
#             ...
# 10772           0.0
# 7346            0.0
# 5302            0.0
# 5298            0.0
# 7386            0.0
# Name: Reviews, Length: 10841, dtype: float64

# %%
ind=df["Reviews"].sort_values(ascending=False).head().index

# %%
df.iloc[ind]["App"]
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: str

# %%
#15.Find Average Rating of Free and Paid Apps
df.groupby("Type")["Rating"].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %%
#16. Find Top 5 Apps Having Maximum Installs
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='str')

# %%
df['Installs'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: str

# %%
df['Installs']=df['Installs'].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 df['Installs']=df['Installs'].astype("float")
#
# File c:\Users\yasin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File c:\Users\yasin\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
df[df['Installs']=="Free"]
# Out:
#                                            App Category  Rating    Reviews    Size Installs Type     Price Content Rating             Genres Last Updated Current Ver Android Ver
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0  3000000.0  1,000+     Free    0  Everyone            NaN  February 11, 2018       1.0.19  4.0 and up         NaN

# %%
df['Installs']=df['Installs'].str.replace("Free","0")

# %%
df['Installs'].sort_values(ascending=False).head().index
# Out:
# Index([1661, 4039, 385, 3562, 4048], dtype='int64')

# %%
df.iloc[df['Installs'].sort_values(ascending=False).head(5).index]["App"].values
# Out:
# <StringArray>
# [                         'Temple Run 2',
#  'Google Duo - High Quality Video Calls',
#                        'Viber Messenger',
#                        'Google Calendar',
#                                'Dropbox']
# Length: 5, dtype: str

# %%
print("Top 5 Apps Having Maximum Installs")
for appname in df.iloc[df['Installs'].sort_values(ascending=False).head().index].values:
 print(appname)
# Out:
# Top 5 Apps Having Maximum Installs
# ['Temple Run 2' 'GAME' 4.3 8118609.0 '62M' '500,000,000+' 'Free' '0'
#  'Everyone' 'Action' 'July 5, 2018' '1.49.1' '4.0 and up']
# ['Google Duo - High Quality Video Calls' 'COMMUNICATION' 4.6 2083237.0
#  'Varies with device' '500,000,000+' 'Free' '0' 'Everyone' 'Communication'
#  'July 31, 2018' '37.1.206017801.DR37_RC14' '4.4 and up']
# ['Viber Messenger' 'COMMUNICATION' 4.3 11334973.0 'Varies with device'
#  '500,000,000+' 'Free' '0' 'Everyone' 'Communication' 'July 18, 2018'
#  'Varies with device' 'Varies with device']
# ['Google Calendar' 'PRODUCTIVITY' 4.2 858230.0 'Varies with device'
#  '500,000,000+' 'Free' '0' 'Everyone' 'Productivity' 'August 6, 2018'
#  'Varies with device' 'Varies with device']
# ['Dropbox' 'PRODUCTIVITY' 4.4 1860844.0 '61M' '500,000,000+' 'Free' '0'
#  'Everyone' 'Productivity' 'August 1, 2018' 'Varies with device'
#  'Varies with device']
